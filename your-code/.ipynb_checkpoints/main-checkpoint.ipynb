# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
from scipy.stats import uniform
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.4390698  2.14225945 2.67787852 2.15978976 2.89996371 2.34583591
#  2.15685212 2.98142851 2.97129151 2.58435544]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
from scipy.stats import uniform
import numpy as np

import matplotlib.pyplot as plt
x = uniform.rvs(size=100)
a = 10
b = 15
randoms  = a + (b-a)*x
print(randoms)
plt.hist(randoms,bins=10)
# your code here
# Out:
# [12.86105398 13.38076953 12.66757222 13.4271607  12.15633093 13.70903499
#  14.98728024 12.72985765 10.11031891 12.11480855 11.53951093 10.47757751
#  10.09583957 12.67084251 11.24209021 14.15970179 10.88269865 11.96402393
#  14.22922442 14.34357404 11.63732886 14.40275289 13.32082204 11.01287371
#  12.54187132 12.24487947 14.48218874 13.38564927 11.00006861 13.55509003
#  12.63915777 14.89258631 12.92228531 14.1816591  12.63021314 12.65389602
#  10.73195116 11.57802401 14.84006116 11.33203797 12.25057144 12.11755072
#  14.07052396 10.33665885 10.63318215 14.45912524 14.90017183 12.07670029
#  11.88118486 12.31816081 10.80338845 12.84948196 11.15784295 12.08343364
#  13.87896929 13.29442412 11.80078843 12.33872217 11.67415604 14.44552749
#  13.48478489 10.16396079 14.74567986 11.44710517 12.97256718 14.95168039
#  13.98035731 10.61356679 12.00044638 14.50870233 14.00801093 13.83098151
#  12.56777086 12.90754948 12.54581827 12.969139   13.17428604 11.41663881
#  10.64699956 14.63078069 13.2556589  12.0213174  10.48619119 13.86299534
#  14.48018681 14.01806874 11.09171861 11.16670319 12.65539291 11.50269319
#  11.5772058  11.58094595 12.05045672 14.92305464 12.0971143  10.41940702
#  13.46327495 10.85150731 14.81790374 10.1152634 ]
# (array([ 8.,  9.,  9., 11., 10., 16.,  9.,  7., 11., 10.]),
#  array([10.09583957, 10.58498364, 11.07412771, 11.56327177, 12.05241584,
#         12.54155991, 13.03070397, 13.51984804, 14.00899211, 14.49813617,
#         14.98728024]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
#  26.41839923 59.82195562 26.29658581 27.64971332 19.46917424 22.45848262
#  18.60625416 29.86790039 26.90622562 57.74109215 33.91216246 52.23297236
#  52.81816086 36.09204709 15.97168553 43.56599122 32.91910303 34.14303188
#  34.77844385 53.85141636 58.17111268 26.41023355]

# %%
plt.hist(randoms1,bins=10)
# Out:
# (array([ 94., 112.,  99., 106., 106., 106., 100.,  95.,  95.,  87.]),
#  array([10.00836446, 15.00389927, 19.99943408, 24.99496889, 29.9905037 ,
#         34.98603851, 39.98157332, 44.97710812, 49.97264293, 54.96817774,
#         59.96371255]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
from scipy.stats import norm

# %%
normal = norm(10,1)
a=normal.rvs(1000,0)
plt.hist(a,bins=50)
# your code here
# Out:
# (array([ 1.,  1.,  2.,  3.,  2.,  2.,  5.,  2.,  6.,  5.,  8., 12., 18.,
#         13., 19., 19., 27., 25., 39., 36., 40., 39., 50., 48., 40., 54.,
#         46., 40., 48., 51., 38., 25., 34., 32., 31., 26., 14., 18., 15.,
#         13.,  8.,  9., 10.,  6.,  5.,  5.,  5.,  2.,  1.,  2.]),
#  array([ 6.95385695,  7.06996691,  7.18607687,  7.30218684,  7.4182968 ,
#          7.53440676,  7.65051673,  7.76662669,  7.88273665,  7.99884662,
#          8.11495658,  8.23106654,  8.34717651,  8.46328647,  8.57939643,
#          8.6955064 ,  8.81161636,  8.92772632,  9.04383629,  9.15994625,
#          9.27605621,  9.39216618,  9.50827614,  9.6243861 ,  9.74049607,
#          9.85660603,  9.97271599, 10.08882596, 10.20493592, 10.32104588,
#         10.43715585, 10.55326581, 10.66937577, 10.78548574, 10.9015957 ,
#         11.01770566, 11.13381563, 11.24992559, 11.36603555, 11.48214552,
#         11.59825548, 11.71436544, 11.83047541, 11.94658537, 12.06269533,
#         12.1788053 , 12.29491526, 12.41102522, 12.52713519, 12.64324515,
#         12.75935511]),
#  <BarContainer object of 50 artists>)

# %% [markdown]
# How are the two distributions different?

# %%
normal = norm(10,50)
b=normal.rvs(1000,0)
plt.hist(b,bins=50)
# your answer below
# Out:
# (array([ 1.,  1.,  2.,  3.,  2.,  2.,  5.,  2.,  6.,  5.,  8., 12., 18.,
#         13., 19., 19., 27., 25., 39., 36., 40., 39., 50., 48., 40., 54.,
#         46., 40., 48., 51., 38., 25., 34., 32., 31., 26., 14., 18., 15.,
#         13.,  8.,  9., 10.,  6.,  5.,  5.,  5.,  2.,  1.,  2.]),
#  array([-142.30715274, -136.50165457, -130.6961564 , -124.89065823,
#         -119.08516006, -113.2796619 , -107.47416373, -101.66866556,
#          -95.86316739,  -90.05766922,  -84.25217105,  -78.44667288,
#          -72.64117471,  -66.83567655,  -61.03017838,  -55.22468021,
#          -49.41918204,  -43.61368387,  -37.8081857 ,  -32.00268753,
#          -26.19718936,  -20.39169119,  -14.58619303,   -8.78069486,
#           -2.97519669,    2.83030148,    8.63579965,   14.44129782,
#           20.24679599,   26.05229416,   31.85779232,   37.66329049,
#           43.46878866,   49.27428683,   55.079785  ,   60.88528317,
#           66.69078134,   72.49627951,   78.30177768,   84.10727584,
#           89.91277401,   95.71827218,  101.52377035,  107.32926852,
#          113.13476669,  118.94026486,  124.74576303,  130.55126119,
#          136.35675936,  142.16225753,  147.9677557 ]),
#  <BarContainer object of 50 artists>)

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
import pandas as pd
data=pd.read_csv('vehicles.csv')
data
data['Fuel Barrels/Year'].hist(bins=50)
# your code here
# Out:
# <AxesSubplot:>

# %%
data
data.mean()
# Out:
# C:\Users\sofia\AppData\Local\Temp/ipykernel_11920/3396388167.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.mean()
# Year                       2000.716400
# Engine Displacement           3.338493
# Cylinders                     5.765076
# Fuel Barrels/Year            17.609056
# City MPG                     17.646139
# Highway MPG                  23.880646
# Combined MPG                 19.929322
# CO2 Emission Grams/Mile     475.316339
# Fuel Cost/Year             1892.598465
# dtype: float64

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
# your code here
data['CO2 Emission Grams/Mile'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# 3. Combined MPG

# %%
# your code here
data['Combined MPG'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
# your answer here
la que se aproxima mas a una distribucion normal es la variable Combined MPG, ya que tiene una distribucion mas uniforme en los datos.

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 1 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
def exponencial(size, mean=10):
    return np.random.exponential(mean, size)

# %%
exponencial(1000, mean=1)

plt.hist(exponencial(1000, mean=1), bins=100, edgecolor='blue') 
plt.title("Exponential Distribution") 
plt.show()
# your code here

# %%
plt.hist(exponencial(1000, mean=100), bins=100, edgecolor='blue') 
plt.title("Exponential Distribution") 
plt.show()

# %% [markdown]
# How are the two distributions different?

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
# your answer here
# Hint: This is same as saying P(x<15)
from scipy.stats import expon
expon.cdf(15,10)
# Out:
# 0.9932620530009145

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
#1-P(x<15)
# your answer here

1-expon.cdf(15,10)
# Out:
# 0.006737946999085476
